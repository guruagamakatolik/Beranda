# %% [markdown]
# <a href="https://colab.research.google.com/github/guruagamakita/guruagamakita.github.io/blob/Main/ms_1_7b_text_to_video_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
prompt = "Seorang anak laki-laki dan anjingnya berjalan di hutan berkabut, gaya animasi petualangan"
